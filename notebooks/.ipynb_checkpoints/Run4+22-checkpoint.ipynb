# %%
# importo librerie utili
import pandas as pd
import math
import numpy as np
import datetime

# %%
# creo la lista con i nomi delle colonne
colNamesInitData_4 = ['40Ar F', 'err40Ar F', '38Ar IC0', 'err38Ar IC0', '36Ar IC1', 'err36Ar IC1','38Ar F', 'err38Ar F','36Ar IC0', 'err36Ar IC0 ', '39Ar F', 'err39Ar F', '37Ar IC0', 'err37Ar IC0' , '35Cl IC1', 'err35Cl IC1', '39Ar IC0',  'err39Ar IC0',  '37Ar IC1', 'err37Ar IC1', 'gainF/IC0', 'err gainF/IC0' , 'gainIC0/IC1', 'err gainIC0/IC1', '40F/36IC1',  'err40F/36IC1',  '40F/36IC0' ,'err40F/36IC0', 'Run', 'Path']
colnames_numeric_4 = ['40Ar F', 'err40Ar F', '38Ar IC0', 'err38Ar IC0', '36Ar IC1', 'err36Ar IC1','38Ar F', 'err38Ar F','36Ar IC0', 'err36Ar IC0 ', '39Ar F', 'err39Ar F', '37Ar IC0', 'err37Ar IC0' , '35Cl IC1', 'err35Cl IC1', '39Ar IC0',  'err39Ar IC0',  '37Ar IC1', 'err37Ar IC1', 'gainF/IC0', 'err gainF/IC0' , 'gainIC0/IC1', 'err gainIC0/IC1', '40F/36IC1',  'err40F/36IC1',  '40F/36IC0' ,'err40F/36IC0']   

# definisco il percorso del file run.4
filePath_4 = "../test_data/Run4.txt"
# importo il file run.4

# %%
# creo la lista con i nomi delle colonne
colNamesInitData_22 = ['40Ar F', 'err40Ar F', '38Ar IC0', 'err38Ar IC0', '36Ar IC1', 'err36Ar IC1','38Ar F', 'err38Ar F','36Ar IC0', 'err36Ar IC0 ', '39Ar F', 'err39Ar F', '37Ar IC0', 'err37Ar IC0' , '35Cl IC1', 'err35Cl IC1', 'gainIC0/IC1', 'err gainIC0/IC1' , '40F/36IC1',  'err40F/36IC1',  '40F/36IC0' ,'err40F/36IC0', 'Run', 'Path']
colnames_numeric_22 = ['40Ar F', 'err40Ar F', '38Ar IC0', 'err38Ar IC0', '36Ar IC1', 'err36Ar IC1','38Ar F', 'err38Ar F','36Ar IC0', 'err36Ar IC0 ', '39Ar F', 'err39Ar F', '37Ar IC0', 'err37Ar IC0' , '35Cl IC1', 'err35Cl IC1', 'gainIC0/IC1', 'err gainIC0/IC1' , '40F/36IC1',  'err40F/36IC1',  '40F/36IC0' ,'err40F/36IC0']
# definisco il percorso del file run.22
filePath_22 = "../test_data/Run22.txt"

# %%
df_Data_4 = pd.read_csv(filePath_4, header = None, index_col= False, names = colNamesInitData_4, sep = '\t|,')
df_Data_4 = df_Data_4.replace(["{", "}"], ["", ""], regex=True)

# si convertono tutte le colonne del dataframe a numeric (float64)
for i in range(len(colnames_numeric_4)):
    df_Data_4[colnames_numeric_4[i]] = pd.to_numeric(df_Data_4[colnames_numeric_4[i]])
    
df_Data_4
# Out:
# C:\Users\teres\anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#         40Ar F  err40Ar F  38Ar IC0   err38Ar IC0  36Ar IC1   err36Ar IC1  \
# 0     0.847000   0.000370  0.000493  3.700000e-07  0.002460  3.900000e-06
# 1     2.300000   0.000870  0.001540  8.500000e-07  0.006340  9.200000e-06
# 2     1.080000   0.000350  0.000750  5.000000e-07  0.002850  5.400000e-06
# 3     0.089300   0.000040  0.000059  1.300000e-07  0.000215  2.700000e-07
# 4     0.578000   0.000270  0.000329  3.000000e-07  0.001530  2.400000e-06
# ...        ...        ...       ...           ...       ...           ...
# 4166  0.143381   0.000050  0.000129  2.500000e-07  0.000410  4.800000e-07
# ...

# %%
df_Data_22 = pd.read_csv(filePath_22, header = None, names = colNamesInitData_22, sep = '\t|,')
# qui si eliminano le graffe, ma forse si può fare in un unico passaggio all'importazione, definendo
# anche legraffe come separatori di elenco e imponendo di considerare separatori consecutivi come uno solo
# nota che ho sovrascritto il dataframe usando lo stesso nome, non serve crearne più copie che si accumulano
# in memoria
df_Data_22 = df_Data_22.replace(["{", "}"], ["", ""], regex=True)

# qui si convertono tutte le colonne del dataframe a numeric (float64), ma sicuramente si può fare
# sopra all'importazione
for i in range(len(colnames_numeric_22)):
    df_Data_22[colnames_numeric_22[i]] = pd.to_numeric(df_Data_22[colnames_numeric_22[i]])

# qui aggiungere le colonne "mancanti"

# qui si visualizza il dataframe importato e pulito
df_Data_22
# Out:
# C:\Users\teres\anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#          40Ar F  err40Ar F  38Ar IC0   err38Ar IC0  36Ar IC1   err36Ar IC1  \
# 0      7.416700   0.002500  0.001269  6.900000e-07  0.001755  3.000000e-06
# 1      6.614000   0.002300  0.001036  6.900000e-07  0.001198  2.100000e-06
# 2      9.369080   0.003800  0.001380  7.100000e-07  0.001129  1.700000e-06
# 3      8.058740   0.003000  0.001139  6.800000e-07  0.000528  7.100000e-07
# 4     11.968100   0.004600  0.001673  1.000000e-06  0.000496  7.000000e-07
# ...         ...        ...       ...           ...       ...           ...
# 1333   0.426141   0.000120  0.003709  2.600000e-06  0.000883  7.200000e-07
# ...

# %%
df_data = pd.concat([df_Data_4, df_Data_22], axis=0)
df_data
# Out:
#         40Ar F  err40Ar F  38Ar IC0   err38Ar IC0  36Ar IC1   err36Ar IC1  \
# 0     0.847000   0.000370  0.000493  3.700000e-07  0.002460  3.900000e-06
# 1     2.300000   0.000870  0.001540  8.500000e-07  0.006340  9.200000e-06
# 2     1.080000   0.000350  0.000750  5.000000e-07  0.002850  5.400000e-06
# 3     0.089300   0.000040  0.000059  1.300000e-07  0.000215  2.700000e-07
# 4     0.578000   0.000270  0.000329  3.000000e-07  0.001530  2.400000e-06
# ...        ...        ...       ...           ...       ...           ...
# 1333  0.426141   0.000120  0.003709  2.600000e-06  0.000883  7.200000e-07
# 1334  0.224427   0.000066  0.003784  2.800000e-06  0.000268  4.000000e-07
# 1335  0.421204   0.000130  0.004853  3.600000e-06  0.000743  7.200000e-07
# 1336  0.585912   0.000160  0.011360  1.100000e-05  0.000572  6.300000e-07
# 1337  0.605563   0.000170  0.012759  1.100000e-05  0.000492  7.100000e-07
#
#         38Ar F  err38Ar F  36Ar IC0  err36Ar IC0   ...  gainF/IC0  \
# ...
